# %%
# %run TestAI.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\OneDrive - The University of Texas at El Paso\Desktop\School\Semester8_Spring-2025\SWE2\TRACE\AIManager\TestAI.py:5
#       1 from Header_AI import *
#       3 AI = AI_Wordlist_Manager()
# ----> 5 addWordlist()
#
# TypeError: AI_Wordlist_Manager.addWordlist() takes 0 positional arguments but 1 was given
